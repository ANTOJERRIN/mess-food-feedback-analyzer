# %%
#this is the first line of code which im seeing from cs-50 series

x=input("enter your name")
print("Hello world, ",x)
print("Hello world,"+x)
# Out:
# enter your name jerrin
# Hello world,  jerrin
# Hello world,jerrin
